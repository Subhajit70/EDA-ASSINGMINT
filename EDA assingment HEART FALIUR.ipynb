# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import statsmodels.stats.proportion as sp

import matplotlib.ticker as mticker

import warnings
warnings.filterwarnings("ignore")

# %%
pd.read_csv("heart_failure_clinical_records_dataset.csv")
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0

# %%
df.info
# Out:
# <bound method DataFrame.info of       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]>

# %%
df.shape
# Out:
# (299, 13)

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.count()
# Out:
# age                         299
# anaemia                     299
# creatinine_phosphokinase    299
# diabetes                    299
# ejection_fraction           299
# high_blood_pressure         299
# platelets                   299
# serum_creatinine            299
# serum_sodium                299
# sex                         299
# smoking                     299
# time                        299
# DEATH_EVENT                 299
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.nunique()
# Out:
# age                          47
# anaemia                       2
# creatinine_phosphokinase    208
# diabetes                      2
# ejection_fraction            17
# high_blood_pressure           2
# platelets                   176
# serum_creatinine             40
# serum_sodium                 27
# sex                           2
# smoking                       2
# time                        148
# DEATH_EVENT                   2
# dtype: int64

# %%
df.value_counts()
# Out:
# age   anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  smoking  time  DEATH_EVENT
# 40.0  0        90                        0         35                 0                    255000.0   1.1               136           1    1        212   0              1
# 65.0  1        160                       1         20                 0                    327000.0   2.7               116           0    0        8     1              1
#                128                       1         30                 1                    297000.0   1.6               136           0    0        20    1              1
#                113                       1         60                 1                    203000.0   0.9               140           0    0        94    0              1
#                68                        1         60                 1                    304000.0   0.8               140           1    0        79    0              1
#                                                                                                                                                                         ..
# 55.0  0        109                       0         35                 0                    254000.0   1.1               139           1    1        60    0              1
#                84                        1         38                 0                    451000.0   1.3               136           0    0        246   0              1
#                66                        0         40                 0                    203000.0   1.0               138           1    0        233   0              1
#                60                        0         35                 0                    228000.0   1.2               135           1    1        90    0              1
# 95.0  1        371                       0         30                 0                    461000.0   2.0               132           1    0        50    1              1
# Length: 299, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Outliers values
plt.figure(figsize=(20, 15))
plt.boxplot(df, labels=df.columns)
plt.show()

# %%
df.age
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
#1.What is the distribution of age among heart failure patients in the dataset?


df.groupby('sex')['age'].unique()
# Out:
# sex
# 0    [65.0, 49.0, 70.0, 48.0, 75.0, 95.0, 50.0, 82....
# 1    [75.0, 55.0, 65.0, 50.0, 90.0, 60.0, 80.0, 62....
# Name: age, dtype: object

# %%
plt.figure(figsize=(10, 7))
plt.hist(df.sex, histtype='bar')
plt.title('Gender of Patients')
plt.show()

# %%
sns.histplot(df.age,kde=True,color="r")
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
 #2 How does the death rate vary with age?

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.DEATH_EVENT.value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
df.groupby('DEATH_EVENT')['age'].describe()
# Out:
#              count       mean        std   min   25%   50%   75%   max
# DEATH_EVENT
# 0            203.0  58.761906  10.637890  40.0  50.0  60.0  65.0  90.0
# 1             96.0  65.215281  13.214556  42.0  55.0  65.0  75.0  95.0

# %%
plt.figure(figsize=(10, 7))
death_age = df.groupby('DEATH_EVENT')['age'].mean()
myexplode = [0.1, 0]
plt.pie(death_age, autopct='%.1f%%', labels=['Alive', 'Dead'], explode=myexplode, shadow=True)
plt.title('Average Ages In Death Cases')
plt.legend(death_age, loc='upper right')
plt.show()

# %%
#²´ What is the percentage of male and female patients in the dataset

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.sex.value_counts(normalize= True)
# Out:
# 1    0.648829
# 0    0.351171
# Name: sex, dtype: float64

# %%
#4.how does the platlet caount vary different age groupes?

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.groupby('platelets')['age'].unique()
# Out:
# platelets
# 25100.0     [70.0]
# 47000.0     [82.0]
# 51000.0     [70.0]
# 62000.0     [60.0]
# 70000.0     [59.0]
#              ...
# 533000.0    [70.0]
# 543000.0    [45.0]
# 621000.0    [72.0]
# 742000.0    [45.0]
# 850000.0    [45.0]
# Name: age, Length: 176, dtype: object

# %%
df.groupby('platelets')['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# platelets
# 25100.0      1.0  70.0  NaN  70.0  70.0  70.0  70.0  70.0
# 47000.0      1.0  82.0  NaN  82.0  82.0  82.0  82.0  82.0
# 51000.0      1.0  70.0  NaN  70.0  70.0  70.0  70.0  70.0
# 62000.0      1.0  60.0  NaN  60.0  60.0  60.0  60.0  60.0
# 70000.0      1.0  59.0  NaN  59.0  59.0  59.0  59.0  59.0
# ...          ...   ...  ...   ...   ...   ...   ...   ...
# 533000.0     1.0  70.0  NaN  70.0  70.0  70.0  70.0  70.0
# 543000.0     1.0  45.0  NaN  45.0  45.0  45.0  45.0  45.0
# 621000.0     1.0  72.0  NaN  72.0  72.0  72.0  72.0  72.0
# 742000.0     1.0  45.0  NaN  45.0  45.0  45.0  45.0  45.0
# 850000.0     1.0  45.0  NaN  45.0  45.0  45.0  45.0  45.0
#
# [176 rows x 8 columns]

# %%
df.platelets.value_counts()
# Out:
# 263358.03    25
# 221000.00     4
# 279000.00     4
# 271000.00     4
# 305000.00     4
#              ..
# 227000.00     1
# 289000.00     1
# 300000.00     1
# 217000.00     1
# 742000.00     1
# Name: platelets, Length: 176, dtype: int64

# %%
plt.figure(figsize=(10, 7))
plt.hist(df.high_blood_pressure, histtype='bar')
plt.title('platelets')
plt.show()

# %%
#5Is there any corealation between crathine and sodium levels?

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(df.loc[:, ['serum_creatinine', 'serum_sodium']].corr(), annot=True)
plt.title('serum_creatinine', 'serum_sodium', loc='left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 plt.figure(figsize=(15, 10))
#       2 sns.heatmap(df.loc[:, ['serum_creatinine', 'serum_sodium']].corr(), annot=True)
# ----> 3 plt.title('serum_creatinine', 'serum_sodium', loc='left')
#       4 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:3012, in title(label, fontdict, loc, pad, y, **kwargs)
#    3010 @_copy_docstring_and_deprecators(Axes.set_title)
#    3011 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3012     return gca().set_title(
#    3013         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:168, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     166 title.update(default)
#     167 if fontdict is not None:
# --> 168     title.update(fontdict)
#     169 title._internal_update(kwargs)
#     170 return title
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/text.py:190, in Text.update(self, kwargs)
#     188 def update(self, kwargs):
#     189     # docstring inherited
# --> 190     kwargs = cbook.normalize_kwargs(kwargs, Text)
#     191     sentinel = object()  # bbox can be None, so use another sentinel.
#     192     # Update fontproperties first, as it has lowest priority.
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1805, in normalize_kwargs(kw, alias_mapping)
#    1802 canonical_to_seen = {}
#    1803 ret = {}  # output dictionary
# -> 1805 for k, v in kw.items():
#    1806     canonical = to_canonical.get(k, k)
#    1807     if canonical in canonical_to_seen:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
#6.how does the prevelence of high blood pressur differ betwwen male and female patient?

# %%
df.groupby('sex')['high_blood_pressure'].value_counts()

# %%
plt.figure(figsize=(10, 7))
plt.hist(df.sex, histtype='bar')
plt.title('Gender of Patients')
plt.show()

# %%
#whats the relation between smoking habit nd occurance of heart faliure??

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.groupby('DEATH_EVENT')['smoking'].value_counts()
# Out:
# DEATH_EVENT  smoking
# 0            0          137
#              1           66
# 1            0           66
#              1           30
# Name: smoking, dtype: int64

# %%
plt.figure(figsize=(10, 7))
death_smok = df.groupby('DEATH_EVENT')['smoking'].value_counts()
myexplode = [0.1, 0, 0.2, 0]
plt.pie(death_smok, autopct='%.1f%%', labels=['Alive-non smoker', 'Alive-smoker', 'Dead-non smoker', 'Dead-smoker'], explode=myexplode, shadow=True)
plt.title('Smoker Patients In Death Cases')
plt.legend(death_smok, loc='upper left')
plt.show()

# %%
#8.are there any noticable patterns in the distrubation death events across the different age groupe??

# %%
df.groupby('DEATH_EVENT')['age'].describe()
# Out:
#              count       mean        std   min   25%   50%   75%   max
# DEATH_EVENT
# 0            203.0  58.761906  10.637890  40.0  50.0  60.0  65.0  90.0
# 1             96.0  65.215281  13.214556  42.0  55.0  65.0  75.0  95.0

# %%
plt.figure(figsize=(10, 7))
death_age = df.groupby('DEATH_EVENT')['age'].mean()
myexplode = [0.1, 0]
plt.pie(death_age, autopct='%.1f%%', labels=['Alive', 'Dead'], explode=myexplode, shadow=True)
plt.title('Average Ages In Death Cases')
plt.legend(death_age, loc='upper right')
plt.show()

# %%
#9 is there any significance difference between patients and without deibaties

# %%
plt.figure(figsize=(10, 7))
plt.hist(df.diabetes, histtype='bar')
plt.title('Diabetic Patients')
plt.show()

# %%
plt.figure(figsize=(10, 7))
death_diab = df.groupby('DEATH_EVENT')['diabetes'].value_counts()
myexplode = [0.1, 0, 0.2, 0]
plt.pie(death_diab, autopct='%.1f%%', labels=['Alive-non diabetic', 'Alive-diabetic', 'Dead-non diabetic', 'Dead-diabetic'], explode=myexplode, shadow=True)
plt.title('Diabetic Patients In Death Cases')
plt.legend(death_diab, loc='upper left')
plt.show()

# %%
# how dose the serum caratinene leve vary with the patient who survied and who dont

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.groupby('DEATH_EVENT')['serum_creatinine'].mean()
# Out:
# DEATH_EVENT
# 0    1.184877
# 1    1.835833
# Name: serum_creatinine, dtype: float64

# %%
plt.figure(figsize=(10, 7))
death_SC = df.groupby('DEATH_EVENT')['serum_creatinine'].mean()
myexplode = [0.1, 0]
plt.pie(death_SC, autopct='%.1f%%', labels=['Alive-avg Serum Creatinine', 'Dead-avg Serum Creatinine'], explode=myexplode, shadow=True)
plt.title('Average values of Serum Creatinine In Death Cases')
plt.legend(death_SC, loc='upper left')
plt.show()

# %%
#complate
